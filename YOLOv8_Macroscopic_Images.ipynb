# %%
import os
HOME = os.getcwd()
print(HOME)
# Out:
# /home/p51pro/efficientdet/yolov8_custom

# %%
from IPython import display
display.clear_output()

import ultralytics
ultralytics.checks()

from ultralytics import YOLO

from IPython.display import display, Image


# !mkdir {HOME}/datasets
# %cd {HOME}/datasets
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.9 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce 940MX, 4046MiB)
# Setup complete ✅ (8 CPUs, 15.5 GB RAM, 534.5/551.1 GB disk)
# mkdir: cannot create directory ‘/home/p51pro/efficientdet/yolov8_custom/datasets’: File exists
# /home/p51pro/efficientdet/yolov8_custom/datasets

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="KIXvpjLqEqhoyURdHBXD")
project = rf.workspace("microbots").project("gendata")
dataset = project.version(4).download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ...
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# ...
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# ...

# %%
# %cd {HOME}
# Out:
# /home/p51pro/efficientdet/yolov8_custom

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=1 batch=1 imgsz=800 plots=True
# Out:
# Ultralytics YOLOv8.0.20 🚀 Python-3.10.9 torch-2.0.1+cu117 CUDA:0 (NVIDIA GeForce 940MX, 4046MiB)
# ...

# %%
# !ls {HOME}/runs/detect/train/
# Out:
# args.yaml
# events.out.tfevents.1684295693.p51pro-HP-Pavilion-Laptop-15-cc1xx.15455.0
# weights

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/confusion_matrix.png', width=600)
# Out:
# /home/p51pro/efficientdet/yolov8_custom

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/results.png', width=600)
# Out:
# /home/p51pro/efficientdet/yolov8_custom

# %%
# %cd {HOME}
Image(filename=f'{HOME}/runs/detect/train3/val_batch0_pred.jpg', width=600)
# Out:
# /home/p51pro/efficientdet/yolov8_custom

# %%
# %cd {HOME}
# !yolo task=detect mode=predict model={HOME}/runs/detect/train2/weights/best.pt conf=0.7 source={dataset.location}/valid/images save=True
# Out:
# /home/p51pro/efficientdet/yolov8_custom
# ^C
# Traceback (most recent call last):
#   File "<frozen importlib._bootstrap_external>", line 153, in _path_is_mode_type
#   File "<frozen importlib._bootstrap_external>", line 147, in _path_stat
# FileNotFoundError: [Errno 2] No such file or directory: '/home/p51pro/anaconda3/lib/python3.10/site-packages/sympy/polys/__init__.cpython-310-x86_64-linux-gnu.so'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/p51pro/anaconda3/bin/yolo", line 5, in <module>
#     from ultralytics.yolo.cfg import entrypoint
#   File "/home/p51pro/anaconda3/lib/python3.10/site-packages/ultralytics/__init__.py", line 5, in <module>
#     from ultralytics.yolo.engine.model import YOLO
#   File "/home/p51pro/anaconda3/lib/python3.10/site-packages/ultralytics/yolo/__init__.py", line 3, in <module>
#     from . import v8
# ...
